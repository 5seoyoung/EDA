# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# 한글 폰트 설정
from matplotlib import font_manager, rc
import platform

your_os = platform.system()
if your_os == 'Linux':
    rc('font', family = 'NanumGothic')
elif your_os == 'Windows':
    ttf = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=ttf).get_name()
    rc('font', family = font_name)
elif your_os == 'Darwin':
    rc('font', family = 'AppleGothic')
rc('axes', unicode_minus = False)

# %%
# 근로소득 변화율과 범죄율 변화율
data = {
    '근로소득': [0.27400133, 0.220069833, 0.146283451, 0.182291117, 0.21267347, 0.206259467, 0.194943921, 0.237109738, 0.147858274, 0.120638038, 0.25002249, 0.201658745, 0.229508376, 0.224680954, 0.212054269, 0.221223816, 0.196659895, 0.213672748, 0.16896898, 0.266914154, 0.284218332, 0.188207276, 0.193290406, 0.267532138, 0.204434805],
    '범죄율': [-0.020188324, -0.122654964, -0.212565185, -0.013973269, -0.054859695, -0.05736505, -0.139550079, -0.139253852, -0.007762971, 0.084619055, -0.095378564, -0.157546603, -0.130718954, -0.184253871, -0.142890791, -0.063714637, -0.016911648, -0.06829619, 0.026611047, -0.165977677, -0.058762581, -0.07455976, -0.132323232, -0.259321178, -0.131028636],
}

# 데이터프레임 생성
df = pd.DataFrame(data)

# 근로소득과 범죄율
x = df['근로소득']
y = df['범죄율']

# 산점도 그리기
plt.figure(figsize=(8, 6))
sns.scatterplot(x=x, y=y)
plt.title('Scatter Plot of 근로소득 vs 범죄율')
plt.xlabel('근로소득')
plt.ylabel('범죄율')
plt.savefig('Scatter Plot of 근로소득 vs 범죄율', bbox_inches='tight')  # bbox_inches='tight'로 설정하여 라벨이 잘리지 않도록 함
plt.show()
plt.show()

# 상관계수 계산 및 출력
print("상관계수:")
print("피어슨 상관계수:", stats.pearsonr(x, y))
print("스피어만 상관계수:", stats.spearmanr(x, y))
print("켄달 상관계수:", stats.kendalltau(x, y))
# Out:
# 상관계수:
# 피어슨 상관계수: PearsonRResult(statistic=-0.3938204861546399, pvalue=0.05143490088338896)
# 스피어만 상관계수: SignificanceResult(statistic=-0.31384615384615383, pvalue=0.1265639797711209)
# 켄달 상관계수: SignificanceResult(statistic=-0.24666666666666665, pvalue=0.0882790830212813)

# %%
# 상권 변화율과 범죄율 변화율
data = {
    '상권': [0.123390096, 0.145376217, 0.119605124, 0.201426006, 0.129474193, 0.112419018, 0.108390795, 0.131410947, 0.149587732, 0.121213553, 0.083314807, 0.108994201, 0.142982872, 0.120308298, 0.096694814, 0.170526152, 0.139271969, 0.141264326, 0.131509388, 0.1173662, 0.087322056, 0.157927515, 0.037581716, -0.015087751, 0.140265238],
    '범죄율': [-0.020188324, -0.122654964, -0.212565185, -0.013973269, -0.054859695, -0.05736505, -0.139550079, -0.139253852, -0.007762971, 0.084619055, -0.095378564, -0.157546603, -0.130718954, -0.184253871, -0.142890791, -0.063714637, -0.016911648, -0.06829619, 0.026611047, -0.165977677, -0.058762581, -0.07455976, -0.132323232, -0.259321178, -0.131028636]
}

# 데이터프레임 생성
df = pd.DataFrame(data)

# 상권변화율과 범죄율
x = df['상권']
y = df['범죄율']

# 산점도 그리기
plt.figure(figsize=(8, 6))
sns.scatterplot(x=x, y=y)
plt.xlabel('상권변화율')
plt.ylabel('범죄율')
plt.title('Scatter Plot of 상권변화율 vs 범죄율')
plt.show()


# 상관계수 계산 및 출력
print("상관계수:")
print("피어슨 상관계수:", stats.pearsonr(x, y))
print("스피어만 상관계수:", stats.spearmanr(x, y))
print("켄달 상관계수:", stats.kendalltau(x, y))
# Out:
# 상관계수:
# 피어슨 상관계수: PearsonRResult(statistic=0.4967785420111378, pvalue=0.011530737020893524)
# 스피어만 상관계수: SignificanceResult(statistic=0.4823076923076923, pvalue=0.014619098711298718)
# 켄달 상관계수: SignificanceResult(statistic=0.3199999999999999, pvalue=0.025387066467633498)

# %%
# 인구밀도 변화율과 범죄율 변화율
data = {
    '인구밀도': [-0.029219614, 0.053716009, -0.062992126, -0.039894722, -0.031149977, -0.042823267, -0.047762971, -0.035778915, -0.054544255, -0.064019698, -0.026001488, -0.045314562, -0.026885043, -0.011235342, -0.06100853, -0.064986086, -0.028208592, -0.02679103, -0.039534621, -0.007285417, -0.048604299, -0.028820211, -0.059683853, -0.041812609, -0.029628266],
    '범죄율': [-0.020188324, -0.122654964, -0.212565185, -0.013973269, -0.054859695, -0.05736505, -0.139550079, -0.139253852, -0.007762971, 0.084619055, -0.095378564, -0.157546603, -0.130718954, -0.184253871, -0.142890791, -0.063714637, -0.016911648, -0.06829619, 0.026611047, -0.165977677, -0.058762581, -0.07455976, -0.132323232, -0.259321178, -0.131028636]
}
df = pd.DataFrame(data)

#인구밀도와 범죄율
x = df['인구밀도']
y = df['범죄율']

# 산점도 그리기
plt.figure(figsize=(8, 6))
sns.scatterplot(x=x, y=y)
plt.xlabel('인구밀도변화율')
plt.ylabel('범죄율')
plt.title('Scatter Plot of 인구밀도변화율vs 범죄율')
plt.show()


# 상관계수 계산 및 출력
print("상관계수:")
print("피어슨 상관계수:", stats.pearsonr(x, y))
print("스피어만 상관계수:", stats.spearmanr(x, y))
print("켄달 상관계수:", stats.kendalltau(x, y))
# Out:
# 상관계수:
# 피어슨 상관계수: PearsonRResult(statistic=-0.15825262548727875, pvalue=0.44992882623687563)
# 스피어만 상관계수: SignificanceResult(statistic=-0.09615384615384616, pvalue=0.6475146685503539)
# 켄달 상관계수: SignificanceResult(statistic=-0.05999999999999999, pvalue=0.6943423762297564)

# %%
# 1인가구 변화율과 범죄율 변화율
data = {
    '1인가구변화율': [0.113601622, 0.322297955, 0.194970905, 0.268662358, 0.213326882, 0.1818476, 0.235379137, 0.337498015, 0.180961304, 0.217162282, 0.172255468, 0.194614565, 0.181980826, 0.168765743, 0.095577378, 0.121962977, 0.162366856, 0.197673574, 0.251946623, 0.270519119, 0.1789291, 0.245294808, 0.152121925, 0.143536552, 0.232546555],
    '범죄율': [-0.020188324, -0.122654964, -0.212565185, -0.013973269, -0.054859695, -0.05736505, -0.139550079, -0.139253852, -0.007762971, 0.084619055, -0.095378564, -0.157546603, -0.130718954, -0.184253871, -0.142890791, -0.063714637, -0.016911648, -0.06829619, 0.026611047, -0.165977677, -0.058762581, -0.07455976, -0.132323232, -0.259321178, -0.131028636]
}

# 데이터프레임 생성
df = pd.DataFrame(data)

# 1인가구변화율과 범죄율
x = df['1인가구변화율']
y = df['범죄율']

# 산점도 그리기
plt.figure(figsize=(10, 6))
sns.scatterplot(x=x, y=y)
plt.xlabel('1인가구변화율')
plt.ylabel('범죄율')
plt.title('Scatter Plot of 1인가구변화율 vs 범죄율')
plt.show()


# 상관계수 계산 및 출력
print("상관계수:")
print("피어슨 상관계수:", stats.pearsonr(x, y))
print("스피어만 상관계수:", stats.spearmanr(x, y))
print("켄달 상관계수:", stats.kendalltau(x, y))
# Out:
# 상관계수:
# 피어슨 상관계수: PearsonRResult(statistic=0.04061833789918104, pvalue=0.8471365173573496)
# 스피어만 상관계수: SignificanceResult(statistic=0.06923076923076923, pvalue=0.7422865391098582)
# 켄달 상관계수: SignificanceResult(statistic=0.046666666666666655, pvalue=0.7638450161401625)

# %%
# 가로등수 변화율과 범죄율 변화율
data = {
    '범죄율': [-0.020188324, -0.122654964, -0.212565185, -0.013973269, -0.054859695, -0.05736505, -0.139550079, -0.139253852, -0.007762971, 0.084619055, -0.095378564, -0.157546603, -0.130718954, -0.184253871, -0.142890791, -0.063714637, -0.016911648, -0.06829619, 0.026611047, -0.165977677, -0.058762581, -0.07455976, -0.132323232, -0.259321178, -0.131028636],
    '가로등': [0.071293879, 0.092015514, 0.009218714, 0.169749972, 0.121040724, 0.105935875, 0.153938106, -0.059497817, 0, 0.104477612, 0.037267081, 0.091053748, 0.083603994, -0.009876543, -0.012428672, 0.038512397, 0.037965616, 0.124038462, 0.110163112, 0.076309549, -0.010082493, 0.03328623, -0.197733405, 0.0050779, 0.33798639]
}

# 데이터프레임 생성
df = pd.DataFrame(data)

# 가로등과 범죄율
x = df['가로등']
y = df['범죄율']

# 산점도 그리기
plt.figure(figsize=(8, 6))
sns.scatterplot(x=x, y=y)
plt.xlabel('가로등')
plt.ylabel('범죄율')
plt.title('Scatter Plot of 가로등 vs 범죄율')
plt.show()


# 상관계수 계산 및 출력
print("상관계수:")
print("피어슨 상관계수:", stats.pearsonr(x, y))
print("스피어만 상관계수:", stats.spearmanr(x, y))
print("켄달 상관계수:", stats.kendalltau(x, y))
# Out:
# 상관계수:
# 피어슨 상관계수: PearsonRResult(statistic=0.2179830833121384, pvalue=0.2952055690040061)
# 스피어만 상관계수: SignificanceResult(statistic=0.34307692307692306, pvalue=0.09315944491694914)
# 켄달 상관계수: SignificanceResult(statistic=0.2133333333333333, pvalue=0.14238229334378744)
